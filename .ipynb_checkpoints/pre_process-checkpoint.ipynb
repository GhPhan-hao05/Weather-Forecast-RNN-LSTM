# %%
from pandas import read_csv
import pandas as pd
from numpy import loadtxt
from numpy import unique
df = read_csv('final_data.csv')
df
# get number of unique values for each column
# counts = df.nunique()
# print(counts)
# record columns to delete
# Out:
#                                           player  ... winger
# 0             /david-de-gea/profil/spieler/59377  ...      0
# 1            /jack-butland/profil/spieler/128899  ...      0
# 2               /tom-heaton/profil/spieler/34130  ...      0
# 3       /lisandro-martinez/profil/spieler/480762  ...      0
# 4          /raphael-varane/profil/spieler/164770  ...      0
# ...                                          ...  ...    ...
# 10749       /aidan-simmons/profil/spieler/867763  ...      1
# 10750        /kusini-yengi/profil/spieler/708099  ...      0
# 10751    /nathanael-blair/profil/spieler/1023268  ...      0
# 10752    /zachary-sapsford/profil/spieler/703657  ...      0
# 10753  /alexander-badolato/profil/spieler/957230  ...      0
#
# [10754 rows x 22 columns]

# %%
counts = df.nunique()
counts
# Out:
# player                 10754
# team                     374
# name                   10584
# position                  16
# height                    47
# age                       30
# appearance               108
# goals                   5329
# assists                 5065
# yellow cards            6291
# second yellow cards     1095
# red cards               1219
# goals conceded           742
# clean sheets             635
# minutes played          5036
# days_injured             772
# games_injured            154
# award                     46
# current_value            128
# highest_value            156
# position_encoded           4
# winger                     2
# dtype: int64

# %%
df['position'],_ = pd.factorize(df['position'])
df['team'],_ = pd.factorize(df['team'])

# Tăng giá trị lên 1 để bắt đầu từ 1 thay vì từ 0
df['position'] += 1
df['team'] += 1
df
# Out:
#                                           player  ...  winger
# 0             /david-de-gea/profil/spieler/59377  ...       0
# 1            /jack-butland/profil/spieler/128899  ...       0
# 2               /tom-heaton/profil/spieler/34130  ...       0
# 3       /lisandro-martinez/profil/spieler/480762  ...       0
# 4          /raphael-varane/profil/spieler/164770  ...       0
# ...                                          ...  ...     ...
# 10749       /aidan-simmons/profil/spieler/867763  ...       1
# 10750        /kusini-yengi/profil/spieler/708099  ...       0
# 10751    /nathanael-blair/profil/spieler/1023268  ...       0
# 10752    /zachary-sapsford/profil/spieler/703657  ...       0
# 10753  /alexander-badolato/profil/spieler/957230  ...       0
#
# [10754 rows x 22 columns]

# %%
df = df.drop(columns=['player', 'name'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 df = df.drop(columns=['player', 'name'], axis=1)
#       2 counts = df.nunique()
#       3 counts
#
# File C:\Users\Admin\envs\machineLearning\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
# ...

# %%
counts = df.nunique()
counts
# Out:
# team                    374
# position                 16
# height                   47
# age                      30
# appearance              108
# goals                  5329
# assists                5065
# yellow cards           6291
# second yellow cards    1095
# red cards              1219
# goals conceded          742
# clean sheets            635
# minutes played         5036
# days_injured            772
# games_injured           154
# award                    46
# current_value           128
# highest_value           156
# position_encoded          4
# winger                    2
# dtype: int64

# %%
data_y=df['current_value']
data_x=df.drop(columns=['current_value'], axis=1)
X= data_x.values
y= data_y.values

# %%
X.shape, y.shape, X[1].shape
# Out:
# ((10754, 19), (10754,), (19,))

# %% [markdown]
# print(1)

# %%
import matplotlib.pyplot as plt


# Vẽ điểm dữ liệu
plt.subplot(1, 3, 1)
plt.scatter(X[:, 1]*100, y, marker='o')#position

plt.subplot(1, 3, 2)
plt.scatter(X[:, 3]*100, y, marker='s')#age

plt.subplot(1, 3, 3)
plt.scatter(X[:, 15], y, marker='v')#injure

# Đặt nhãn cho trục x và y


plt.tight_layout() 
plt.show()
